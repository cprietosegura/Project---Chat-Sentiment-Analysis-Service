# %%
import requests

# %%
data = requests.get('http://localhost:8080/chat/John Wick').json()

# %%
data
# Out:
# [{'_id': {'$oid': '5de15ccad5ac134632cc635d'},
#   'datetime': '2019-10-17 10:15:41',
#   'idChat': 0,
#   'idMessage': 0,
#   'idUser': 0,
#   'text': 'Hey Mike, whats up??',
#   'userName': 'John Wick'},
#  {'_id': {'$oid': '5de15ccad5ac134632cc635f'},
#   'datetime': '2019-10-17 10:17:31',
#   'idChat': 0,
#   'idMessage': 2,
#   'idUser': 0,
#   'text': 'No, had to work. How was it?',
#   'userName': 'John Wick'},
#  {'_id': {'$oid': '5de15ccad5ac134632cc6361'},
#   'datetime': '2019-10-17 10:19:41',
#   'idChat': 0,
#   'idMessage': 4,
#   'idUser': 0,
#   'text': 'No way! 😮️',
#   'userName': 'John Wick'},
#  {'_id': {'$oid': '5de15ccad5ac134632cc6363'},
#   'datetime': '2019-10-17 10:21:41',
#   'idChat': 0,
#   'idMessage': 6,
#   'idUser': 0,
#   'text': 'I bet people went crazy',
#   'userName': 'John Wick'},
#  {'_id': {'$oid': '5de15ccad5ac134632cc6365'},
#   'datetime': '2019-10-17 10:23:41',
#   'idChat': 0,
#   'idMessage': 8,
#   'idUser': 0,
# ...

# %%
url='http://localhost:8080/adduser'

# %%
new_doc = {'userName': 'Walter White', 
            'text': "I'm the one who knocks"}

requests.post(url, data=new_doc)
# Out:
# <Response [200]>

# %%
res
# Out:
# <Response [200]>

# %%
url='http://localhost:8080/add'
params={'autor':'chiquito',
       'chiste':'prueba5'}
requests.post(url, data=params).text
