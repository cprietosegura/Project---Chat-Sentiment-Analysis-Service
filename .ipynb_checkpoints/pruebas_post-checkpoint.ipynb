# %%
import requests

# %% [markdown]
# Aquí pedimos todos los mensajes de un usuario

# %%
#data = requests.get('http://localhost:8080/John Wick').json()
url='http://localhost:8080/John Wick'

# %%
requests.get(url).json()
# Out:
# [{'text': 'Hey Mike, whats up??', 'userName': 'John Wick'},
#  {'text': 'No, had to work. How was it?', 'userName': 'John Wick'},
#  {'text': 'No way! 😮️', 'userName': 'John Wick'},
#  {'text': 'I bet people went crazy', 'userName': 'John Wick'},
#  {'text': 'Motherfucker! Hungover? 😵️', 'userName': 'John Wick'},
#  {'text': 'Sure, boss.', 'userName': 'John Wick'},
#  {'text': 'I do! I just dont feel appreciated in my job',
#   'userName': 'John Wick'},
#  {'text': 'I dunno...', 'userName': 'John Wick'},
#  {'text': 'Maybe', 'userName': 'John Wick'},
#  {'text': 'Thank you, boss! I feel much better...', 'userName': 'John Wick'}]

# %% [markdown]
# Aquí añadimos un usuario con un mensaje

# %%
url='http://localhost:8080/adduser'

# %%
new_doc = {'userName': 'Walter White', 
            'text': "I'm the one who knocks"}

requests.post(url, data=new_doc)
# Out:
# <Response [200]>

# %% [markdown]
# Aquí pedimos todos los mensajes de un chat

# %%
url='http://localhost:8080/chat/3/list'
requests.get(url).json()
# Out:
# [{'text': 'I want pictures of Spiderman and I want them now!',
#   'userName': 'J. Jonah Jameson'},
#  {'text': 'Sure, boss.', 'userName': 'John Wick'},
#  {'text': 'Youve got to take me seriously.', 'userName': 'J. Jonah Jameson'},
#  {'text': 'I do! I just dont feel appreciated in my job',
#   'userName': 'John Wick'},
#  {'text': 'Thats why youve got to get those damm pictures!!',
#   'userName': 'J. Jonah Jameson'},
#  {'text': 'I dunno...', 'userName': 'John Wick'},
#  {'text': 'Get the god damn motherfucking fuckity fuck bloody ballsack pictures',
#   'userName': 'J. Jonah Jameson'},
#  {'text': 'Maybe', 'userName': 'John Wick'},
#  {'text': 'Youve got to! And I believe in you',
#   'userName': 'J. Jonah Jameson'},
#  {'text': 'Thank you, boss! I feel much better...', 'userName': 'John Wick'}]

# %%
todo=requests.get('http://localhost:8080').json()

# %%
todo
# Out:
# [{'_id': {'$oid': '5de2c43cc6e79196c303ad2b'},
#   'datetime': '2019-10-17 10:15:41',
#   'idChat': 0,
#   'idMessage': 0,
#   'idUser': 0,
#   'text': 'Hey Mike, whats up??',
#   'userName': 'John Wick'},
#  {'_id': {'$oid': '5de2c43cc6e79196c303ad2c'},
#   'datetime': '2019-10-17 10:16:59',
#   'idChat': 0,
#   'idMessage': 1,
#   'idUser': 1,
#   'text': 'Dude!!! 😀️ Did you watch the game last night?',
#   'userName': 'Mike Wazowski'},
#  {'_id': {'$oid': '5de2c43cc6e79196c303ad2d'},
#   'datetime': '2019-10-17 10:17:31',
#   'idChat': 0,
#   'idMessage': 2,
#   'idUser': 0,
#   'text': 'No, had to work. How was it?',
#   'userName': 'John Wick'},
#  {'_id': {'$oid': '5de2c43cc6e79196c303ad2e'},
#   'datetime': '2019-10-17 10:18:41',
#   'idChat': 0,
#   'idMessage': 3,
#   'idUser': 1,
#   'text': 'Awesome! Boyander scored 3 goals!',
#   'userName': 'Mike Wazowski'},
#  {'_id': {'$oid': '5de2c43cc6e79196c303ad2f'},
#   'datetime': '2019-10-17 10:19:41',
#   'idChat': 0,
# ...

# %%
"""chats=[]

for t in todo: 
    
    if t['idChat']==0:
        #chat'{}'.format(t['idChat'])={}
        chat['Chatid']=t['idChat']
        chat['text']=t['text']
        chat['idUser']=t['idUser']
        chats.append(chat)"""

# %%
#chats
